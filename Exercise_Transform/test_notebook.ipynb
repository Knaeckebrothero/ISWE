# %%
import pandas as pd

# %%
raw_data = pd.read_csv('./FinancialSample.csv',delimiter=';')

# %%
raw_data.head(10)
# Out:
#             Segment  Country     Product   Discount Band  Units Sold  \
# 0        Government   Canada   Carretera            None      1618,5
# 1        Government  Germany   Carretera            None        1321
# 2         Midmarket   France   Carretera            None        2178
# 3         Midmarket  Germany   Carretera            None         888
# 4         Midmarket   Mexico   Carretera            None        2470
# 5        Government  Germany   Carretera            None        1513
# 6         Midmarket  Germany     Montana            None         921
# 7  Channel Partners   Canada     Montana            None        2518
# 8        Government   France     Montana            None        1899
# 9  Channel Partners  Germany     Montana            None        1545
#
#    Manufacturing Price   Sale Price    Gross Sales   Discounts   \
# 0                $3,00       $20,00     $32.370,00        $-
# 1                $3,00       $20,00     $26.420,00        $-
# ...

# %%
raw_data.tail(10)
# Out:
#               Segment                   Country    Product   Discount Band   \
# 690        Government  United States of America        VTT            High
# 691         Midmarket                   Germany        VTT            High
# 692        Enterprise                    Canada        VTT            High
# 693        Enterprise                   Germany        VTT            High
# 694        Government                    France        VTT            High
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#     Units Sold  Manufacturing Price   Sale Price    Gross Sales   \
# 690        267              $250,00       $20,00      $5.340,00
# ...

# %%
raw_data.dtypes
# Out:
# Segment                  object
# Country                  object
#  Product                 object
#  Discount Band           object
# Units Sold               object
#  Manufacturing Price     object
#  Sale Price              object
#  Gross Sales             object
#  Discounts               object
#   Sales                  object
#  COGS                    object
#  Profit                  object
# Date                     object
# Month Number              int64
#  Month Name              object
# Year                      int64
# dtype: object

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4   Units Sold             700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %%
raw_data.sample(10)
# Out:
#               Segment                   Country     Product   Discount Band   \
# 444        Government  United States of America       Paseo          Medium
# 484        Government                   Germany         VTT            High
# 133        Government                   Germany         VTT             Low
# 635        Government                    Canada     Montana            High
# 373        Government                   Germany       Paseo          Medium
# 228         Midmarket                    Mexico   Carretera          Medium
# 454  Channel Partners                    France    Amarilla          Medium
# 517        Government                    Canada       Paseo            High
# 41          Midmarket                   Germany         VTT            None
# 459        Enterprise                    France   Carretera            High
#
#     Units Sold  Manufacturing Price   Sale Price      Gross Sales   \
# ...

# %%
raw_data["Segment"]
# Out:
# 0            Government
# 1            Government
# 2             Midmarket
# 3             Midmarket
# 4             Midmarket
#              ...
# 695      Small Business
# 696      Small Business
# 697          Government
# 698          Government
# 699    Channel Partners
# Name: Segment, Length: 700, dtype: object

# %%
raw_data["Segment"].shape
# Out:
# (700,)

# %%
raw_data.shape
# Out:
# (700, 16)

# %%
raw_data.loc[raw_data["Segment"] == "Government", "Segment"].head(1)
# Out:
# 0    Government
# Name: Segment, dtype: object

# %%
raw_data["Date"] = pd.to_datetime(raw_data["Date"])
raw_data["Date"].sample(10)
# Out:
# 403   2014-01-06
# 274   2014-01-06
# 491   2014-01-09
# 229   2014-01-12
# 418   2013-01-10
# 172   2014-01-05
# 344   2014-01-09
# 446   2014-01-10
# 232   2014-01-07
# 499   2014-01-03
# Name: Date, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
def tr(d):
    return d.strftime('%Y-%m-%d')

raw_data["Date"].transform(tr)
# Out:
# 0      2014-01-01
# 1      2014-01-01
# 2      2014-01-06
# 3      2014-01-06
# 4      2014-01-06
#           ...
# 695    2014-01-03
# 696    2014-01-10
# 697    2014-01-02
# 698    2014-01-04
# 699    2014-01-05
# Name: Date, Length: 700, dtype: object

# %%
raw_data["Date"]
# Out:
# 0     2014-01-01
# 1     2014-01-01
# 2     2014-01-06
# 3     2014-01-06
# 4     2014-01-06
#          ...
# 695   2014-01-03
# 696   2014-01-10
# 697   2014-01-02
# 698   2014-01-04
# 699   2014-01-05
# Name: Date, Length: 700, dtype: datetime64[ns]

# %%
raw_data = raw_data.rename(columns=lambda x: x.strip())

# %%
raw_data.loc[:,["Product","Profit","COGS","Sales"]]
# Out:
#          Product        Profit           COGS          Sales
# 0     Carretera    $16.185,00     $16.185,00     $32.370,00
# 1     Carretera    $13.210,00     $13.210,00     $26.420,00
# 2     Carretera    $10.890,00     $21.780,00     $32.670,00
# 3     Carretera     $4.440,00      $8.880,00     $13.320,00
# 4     Carretera    $12.350,00     $24.700,00     $37.050,00
# ..           ...           ...            ...            ...
# 695    Amarilla    $12.375,00    $618.750,00    $631.125,00
# 696    Amarilla     $2.730,00    $136.500,00    $139.230,00
# 697     Montana     $1.299,60      $6.840,00      $8.139,60
# 698       Paseo       $686,85      $3.615,00      $4.301,85
# 699         VTT    $13.003,20      $5.418,00     $18.421,20
#
# [700 rows x 4 columns]
